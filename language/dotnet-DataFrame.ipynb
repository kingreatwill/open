// %% [markdown]
// [this doc on github](https://github.com/dotnet/interactive/tree/master/samples/notebooks/csharp/Samples)

// %%
#r "nuget:Microsoft.Data.Analysis,0.2.0"
using Microsoft.Data.Analysis;

// %%
PrimitiveDataFrameColumn<DateTime> dateTimes = new PrimitiveDataFrameColumn<DateTime>("DateTimes"); // Default length is 0.
PrimitiveDataFrameColumn<int> ints = new PrimitiveDataFrameColumn<int>("Ints", 3); // Makes a column of length 3. Filled with nulls initially
StringDataFrameColumn strings = new StringDataFrameColumn("Strings", 3); // Makes a column of length 3. Filled with nulls initially

// %%
// Append 3 values to dateTimes
dateTimes.Append(DateTime.Parse("2019/01/01"));
dateTimes.Append(DateTime.Parse("2019/01/01"));
dateTimes.Append(DateTime.Parse("2019/01/02"));

// %%
DataFrame df = new DataFrame(dateTimes, ints, strings ); // This will throw if the columns are of different lengths

// %%
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr></tbody></table>

// %%
using Microsoft.AspNetCore.Html;
Formatter.Register<DataFrame>((df, writer) =>
{
    var headers = new List<IHtmlContent>();
    headers.Add(th(i("index")));
    headers.AddRange(df.Columns.Select(c => (IHtmlContent) th(c.Name)));
    var rows = new List<List<IHtmlContent>>();
    var take = 20;
    for (var i = 0; i < Math.Min(take, df.Rows.Count); i++)
    {
        var cells = new List<IHtmlContent>();
        cells.Add(td(i));
        foreach (var obj in df.Rows[i])
        {
            cells.Add(td(obj));
        }
        rows.Add(cells);
    }
    
    var t = table(
        thead(
            headers),
        tbody(
            rows.Select(
                r => tr(r))));
    
    writer.Write(t);
}, "text/html");

// %%
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr></tbody></table>

// %%
// To change a value directly through df
df[0, 1] = 10; // 0 is the rowIndex, and 1 is the columnIndex. This sets the 0th value in the Ints columns to 10
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">10</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr></tbody></table>

// %%
// Modify ints and strings columns by indexing
ints[1] = 100;
strings[1] = "Foo!";
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">10</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">100</div></td><td>Foo!</td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr></tbody></table>

// %%
// Indexing can throw when types don't match.
// ints[1] = "this will throw because I am a string";  
// Info can be used to figure out the type of data in a column. 
df.Info()
// Out:
// <table><thead><th><i>index</i></th><th>Info</th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td>DataType</td><td>System.DateTime</td><td>System.Int32</td><td>System.String</td></tr><tr><td><div class="dni-plaintext">1</div></td><td>Length (excluding null values)</td><td>3</td><td>2</td><td>3</td></tr></tbody></table>

// %%
// Add 5 to ints through the DataFrame
df["Ints"].Add(5, inPlace: true);
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">15</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">105</div></td><td>Foo!</td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr></tbody></table>

// %%
// We can also use binary operators. Binary operators produce a copy, so assign it back to our Ints column 
df["Ints"] = (ints / 5) * 100;
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">300</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">2100</div></td><td>Foo!</td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">&lt;null&gt;</div></td><td><div class="dni-plaintext">&lt;null&gt;</div></td></tr></tbody></table>

// %%
// Fill nulls in our columns, if any. Ints[2], Strings[0] and Strings[1] are null
df["Ints"].FillNulls(-1, inPlace: true);
df["Strings"].FillNulls("Bar", inPlace: true);
df
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">300</div></td><td>Bar</td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">2100</div></td><td>Foo!</td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">-1</div></td><td>Bar</td></tr></tbody></table>

// %%
// To inspect the first row
DataFrameRow row0 = df.Rows[0];
row0
// Out:
// <table><tbody><td><i></i></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">300</div></td><td>Bar</td></tbody></table>

// %%
using Microsoft.AspNetCore.Html;
Formatter.Register<DataFrameRow>((dataFrameRow, writer) =>
{
    var cells = new List<IHtmlContent>();
    cells.Add(td(i));
    foreach (var obj in dataFrameRow)
    {
        cells.Add(td(obj));
    }
    
    var t = table(
        tbody(
            cells));
    
    writer.Write(t);
}, "text/html");

// %%
row0
// Out:
// <table><tbody><td><i></i></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">300</div></td><td>Bar</td></tbody></table>

// %%
// Filter rows based on equality
PrimitiveDataFrameColumn<bool> boolFilter = df["Strings"].ElementwiseEquals("Bar");
boolFilter
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><div class="dni-plaintext">True</div></td></tr><tr><td>1</td><td><div class="dni-plaintext">False</div></td></tr><tr><td>2</td><td><div class="dni-plaintext">True</div></td></tr></tbody></table>

// %%
DataFrame filtered = df.Filter(boolFilter);
filtered
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">300</div></td><td>Bar</td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">-1</div></td><td>Bar</td></tr></tbody></table>

// %%
// Sort our dataframe using the Ints column
DataFrame sorted = df.Sort("Ints");
sorted
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">-1</div></td><td>Bar</td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">300</div></td><td>Bar</td></tr><tr><td><div class="dni-plaintext">2</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">2100</div></td><td>Foo!</td></tr></tbody></table>

// %%
// GroupBy 
GroupBy groupBy = df.GroupBy("DateTimes");
// Count of values in each group
DataFrame groupCounts = groupBy.Count();
groupCounts
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th><th>Strings</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">2</div></td><td><div class="dni-plaintext">2</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">1</div></td><td><div class="dni-plaintext">1</div></td></tr></tbody></table>

// %%
// Alternatively find the sum of the values in each group in Ints
DataFrame intsGroupSum = groupBy.Sum("Ints");
intsGroupSum
// Out:
// <table><thead><th><i>index</i></th><th>DateTimes</th><th>Ints</th></thead><tbody><tr><td><div class="dni-plaintext">0</div></td><td><span>2019-01-01 00:00:00Z</span></td><td><div class="dni-plaintext">2400</div></td></tr><tr><td><div class="dni-plaintext">1</div></td><td><span>2019-01-02 00:00:00Z</span></td><td><div class="dni-plaintext">-1</div></td></tr></tbody></table>

// %%
using XPlot.Plotly;
using System.Linq;

// %%
#r "nuget:MathNet.Numerics,4.9.0"

// %%
using MathNet.Numerics.Distributions;
double mean = 0;
double stdDev = 0.1;

MathNet.Numerics.Distributions.Normal normalDist = new Normal(mean, stdDev);

// %%
PrimitiveDataFrameColumn<double> doubles = new PrimitiveDataFrameColumn<double>("Normal Distribution", normalDist.Samples().Take(1000));
display(Chart.Plot(
    new Graph.Histogram()
    {
        x = doubles,
        nbinsx = 30
    }
));
// Out:
// <div id="49f1ea53-d762-4043-a5dc-0cd796addf2b" style="width: 900px; height: 500px;"></div>
// <script type="text/javascript">
//
// var renderPlotly = function() {
//     var xplotRequire = require.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}}) || require;
//     xplotRequire(['plotly'], function(Plotly) {
//
//             var data = [{"type":"histogram","x":[-0.14287688404673055,-0.10475912860491461,0.011488996619912723,-0.08089656051622109,0.05307676114034768,0.010501044546515459,0.10117760500528346,0.2123776128565824,0.058953644783223375,0.04373308870802784,0.08053158147118483,0.0775437574501779,0.09505292361106267,-0.18168491008650484,-0.02617620537418351,0.03153320017782756,0.032843333472123995,0.09506779752631989,-0.22975024795797117,-0.008167315791507984,0.022095922843037755,-0.040558199058089626,-0.017706242542091057,-0.17261482906540773,-0.015085121215250033,-0.04841162406445496,0.041196925889153926,0.006041676432631388,0.011594087421581356,-0.017851079416576914,0.018763333861953498,-0.06246790793020249,0.04344834408843588,0.06820438514355484,-0.0026311636153784224,-0.14117